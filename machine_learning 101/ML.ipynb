# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=pd.read_csv('dataset for example.csv')
sns.relplot(data=a,x="age",y="gender",hue="height",size="weight",col="likeness",kind="line",size_order=["T1","T2"],height=5,aspect=.75,facet_kws=dict(sharex=False))
