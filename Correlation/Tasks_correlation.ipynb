# %% [markdown]
# # Assignment

# %% [markdown]
# #### how to get covariance with different ways

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# import dataset
kashti = sns.load_dataset('titanic')
phool = sns.load_dataset('iris')

# %%
# assignment: 
from statistics import covariance
covariance(kashti['age'],kashti['fare'])
# Out:
# nan

# %% [markdown]
# #### 4,5 plots with different types of correlation

# %%
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
kashti.corr()
# 1 means highlly correlated
# -1 means highlly not correlated
# negative value (-) means not correlated
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
corr =  kashti.corr(method='pearson') # for normal data
corr
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
corr1 = kashti.corr(method='spearman') # for non-gaussian distribution
corr1
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.339668 -0.052565  0.088879  0.138266  0.323736
# pclass     -0.339668  1.000000 -0.361666 -0.043019 -0.022801 -0.688032
# age        -0.052565 -0.361666  1.000000 -0.182061 -0.254212  0.135051
# sibsp       0.088879 -0.043019 -0.182061  1.000000  0.450014  0.447113
# parch       0.138266 -0.022801 -0.254212  0.450014  1.000000  0.410074
# fare        0.323736 -0.688032  0.135051  0.447113  0.410074  1.000000
# adult_male -0.557080  0.099351  0.257641 -0.307948 -0.397286 -0.308894
# alone      -0.203367  0.135896  0.167293 -0.828215 -0.683719 -0.531472
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.099351  0.135896
# age           0.257641  0.167293
# sibsp        -0.307948 -0.828215
# parch        -0.397286 -0.683719
# fare         -0.308894 -0.531472
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
# to see positive correlation
sns.regplot(kashti['survived'],kashti['age'], data= kashti)
# Out:
# C:\Users\Anonymous\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
# to see positive correlation
sns.regplot(phool['sepal_width'],phool['petal_width'], data= phool)
# Out:
# C:\Users\Anonymous\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
sns.regplot(phool['petal_length'],phool['petal_width'], data= phool)
# almost 0 correlation
# Out:
# C:\Users\Anonymous\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sns.regplot(kashti['pclass'],kashti['alone'], data= kashti)
# Out:
# C:\Users\Anonymous\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pclass', ylabel='alone'>

# %%
# apply corr function
corr = kashti.corr(method='pearson')  # for normal data
# heat map of correlation
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
# apply corr function
corr = kashti.corr(method='pearson')  # for normal data
# heat map of correlation
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### IMP

# %%
# 0.5 or > then that so we say highly positively correlated 
# -0.5 or > then that so we say highly negatively correlated

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_107e9_row0_col0, #T_107e9_row1_col1, #T_107e9_row2_col2, #T_107e9_row3_col3, #T_107e9_row4_col4, #T_107e9_row5_col5, #T_107e9_row6_col6, #T_107e9_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_107e9_row0_col1, #T_107e9_row4_col6 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_107e9_row0_col2 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_107e9_row0_col3 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_107e9_row0_col4, #T_107e9_row1_col3, #T_107e9_row1_col6 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_107e9_row0_col5, #T_107e9_row5_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_107e9_row0_col6, #T_107e9_row1_col2, #T_107e9_row1_col5, #T_107e9_row3_col7, #T_107e9_row4_col7, #T_107e9_row5_col1, #T_107e9_row6_col0, #T_107e9_row7_col3, #T_107e9_row7_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_107e9_row0_col7, #T_107e9_row5_col6 {
# ...

# %%
sns.pairplot(corr1)

# %%
# to divide these in categories
#or# we can change the points based on category
# import a new dataset
#penguins = sns.load_dataset("penguins")
sns.pairplot(phool)
sns.pairplot(phool, hue="species")

# %%
# we can convert this into histograms
sns.pairplot(phool, hue="species", diag_kind="hist")

# %%
# to make one sided
sns.pairplot(phool, hue="species", diag_kind="hist", corner=True)

# %%
phool.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# calculate pearson's correlation
from scipy.stats import pearsonr
corr,_ = pearsonr(phool['sepal_length'],phool['petal_length'])
print('Pearsons correlation: %.3f' % corr) 
# spearman can be taken with same method
# Out:
# Pearsons correlation: 0.872

# %%
from scipy.stats import spearmanr
corr, _ = spearmanr(phool['sepal_length'], phool['petal_length'])
print('Spearmanr correlation: %.3f' % corr)
# Out:
# Spearmanr correlation: 0.882
